# %% [markdown]
# <a href="https://colab.research.google.com/github/Park-wonil/Math-for-Robotics/blob/main/vis_vectors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install koreanize-matplotlib
# Out:
# Requirement already satisfied: koreanize-matplotlib in /usr/local/lib/python3.13/dist-packages (0.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from koreanize-matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->koreanize-matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->koreanize-matplotlib) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->koreanize-matplotlib) (1.5.1)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.13/dist-packages (from matplotlib->koreanize-matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->koreanize-matplotlib) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->koreanize-matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->koreanize-matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib->koreanize-matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.17.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import koreanize_matplotlib

# %% [markdown]
# ### Load Data and Create Subset

# %%
df = pd.read_excel('BME_MBTI_2026.xlsx')
print(df.shape)
df_ = df[::8]
df_
# Out:
# (74, 5)
#                Name    EI    NS    TF    JP
# 0             검은고양이  0.64 -0.34 -0.40  0.14
# 8               김주호  0.40 -0.20 -0.20  0.60
# 16               미뇽  0.40 -0.80  0.10  0.70
# 24              박선주  0.22  0.66  0.50  0.78
# 32               수달  0.52 -0.22 -0.08 -0.12
# 40              최민지 -0.84 -0.12 -0.78 -0.96
# 48  Marcus rashford -0.50 -0.02 -0.12  0.02
# 56                O  0.56  0.12 -0.60  0.80
# 64              김아연 -0.44 -0.32  0.04 -0.12
# 72              joy  0.02 -0.56 -0.04 -0.12

# %% [markdown]
# ### 2D Vector Visualization (EI and TF)

# %%
# Extract EI and TF data from df_
data_2d = df_[['EI', 'TF']].to_numpy()
names_2d = df_['Name'].tolist()

fig, ax = plt.subplots(figsize=(10, 10))

# Plotting vectors from origin (0,0)
origin_2d = np.zeros(data_2d.shape)

# Create a list of colors, one for each data point
colors = plt.cm.viridis(np.linspace(0, 1, len(data_2d)))

ax.quiver(origin_2d[:, 0], origin_2d[:, 1], data_2d[:, 0], data_2d[:, 1], color=colors, angles='xy', scale_units='xy', scale=1)

# Add names at the end of each arrow
for i, (x, y) in enumerate(data_2d):
    ax.text(x, y, names_2d[i])

# Set limits and labels
max_val_2d = 1.1 #np.max(np.abs(data_2d))
ax.set_xlim([-max_val_2d, max_val_2d])
ax.set_ylim([-max_val_2d, max_val_2d])
ax.set_xlabel('EI')
ax.set_ylabel('TF')
ax.set_title('2D Vector Representation of EI and TF')
ax.grid()
plt.show()

# %% [markdown]
# ### 2D Vector Visualization (EI and TF) - Points

# %%
# Extract EI and TF data from df_
data_2d = df_[['EI', 'TF']].to_numpy()
names_2d = df_['Name'].tolist()

fig, ax = plt.subplots(figsize=(10, 10))

# Plotting vectors from origin (0,0)
origin_2d = np.zeros(data_2d.shape)

# Create a list of colors, one for each data point
colors = plt.cm.viridis(np.linspace(0, 1, len(data_2d)))

ax.scatter(data_2d[:, 0], data_2d[:, 1], color=colors)

# Add names at the end of each arrow
for i, (x, y) in enumerate(data_2d):
    ax.text(x, y, names_2d[i])

# Set limits and labels
max_val_2d = 1.1 #np.max(np.abs(data_2d))
ax.set_xlim([-max_val_2d, max_val_2d])
ax.set_ylim([-max_val_2d, max_val_2d])
ax.set_xlabel('EI')
ax.set_ylabel('TF')
ax.set_title('2D Vector Representation of EI and TF')
ax.grid()
plt.show()

# %% [markdown]
# ### Normalized 2D Vector Visualization (EI and TF)

# %%
# Extract EI and TF data from df_
data_2d = df_[['EI', 'TF']].to_numpy()
names_2d = df_['Name'].tolist()

fig, ax = plt.subplots(figsize=(10, 10))

# Normalize the data to make all vectors have a length of 1
norms_2d = np.linalg.norm(data_2d, axis=1)
normalized_data_2d = data_2d / norms_2d[:, np.newaxis]

# Plotting vectors from origin (0,0)
origin_2d = np.zeros(normalized_data_2d.shape)

# Create a list of colors, one for each data point
colors = plt.cm.viridis(np.linspace(0, 1, len(normalized_data_2d)))

ax.quiver(origin_2d[:, 0], origin_2d[:, 1], normalized_data_2d[:, 0], normalized_data_2d[:, 1], color=colors, angles='xy', scale_units='xy', scale=1)

# Add names at the end of each arrow
for i, (x, y) in enumerate(normalized_data_2d):
    ax.text(x, y, names_2d[i])

# Set limits and labels
# Since vectors are normalized to length 1, the limits can be set to be slightly larger than 1
ax.set_xlim([-1.1, 1.1])
ax.set_ylim([-1.1, 1.1])
ax.set_xlabel('EI')
ax.set_ylabel('TF')
ax.set_title('2D Vector Representation of EI and TF (Normalized)')
ax.grid()
plt.show()

# %% [markdown]
# ### Extract 3D Subset Data

# %%
# Extract the data for EI, TF, and JP from the df_ dataframe
data_3d_subset = df_[['EI', 'TF', 'JP']].to_numpy()
names_3d_subset = df_['Name'].tolist()
print(data_3d_subset[:5])
# Out:
# [[ 0.64 -0.4   0.14]
#  [ 0.4  -0.2   0.6 ]
#  [ 0.4   0.1   0.7 ]
#  [ 0.22  0.5   0.78]
#  [ 0.52 -0.08 -0.12]]

# %% [markdown]
# ### 3D Vector Visualization (Subset Data)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plotting lines from origin (0,0,0)
origin_3d_subset = np.zeros(data_3d_subset.shape)

# Create a list of colors, one for each data point
colors_3d_subset = plt.cm.viridis(np.linspace(0, 1, len(data_3d_subset)))

# Plotting lines
for i in range(len(data_3d_subset)):
    ax.plot([origin_3d_subset[i, 0], data_3d_subset[i, 0]],
            [origin_3d_subset[i, 1], data_3d_subset[i, 1]],
            [origin_3d_subset[i, 2], data_3d_subset[i, 2]],
            color=colors_3d_subset[i])

# Set labels
ax.set_xlabel('EI')
ax.set_ylabel('TF')
ax.set_zlabel('JP')

ax.set_title('3D Line Representation of EI, TF, and JP (Subset Data)')

# Setting limits to see the lines clearly
max_val_3d_subset = 1.2 #np.max(np.abs(data_3d_subset))
ax.set_xlim([-max_val_3d_subset, max_val_3d_subset])
ax.set_ylim([-max_val_3d_subset, max_val_3d_subset])
ax.set_zlim([-max_val_3d_subset, max_val_3d_subset])

# Add text labels at the end of each line
for i in range(len(data_3d_subset)):
    ax.text(data_3d_subset[i, 0], data_3d_subset[i, 1], data_3d_subset[i, 2], names_3d_subset[i])

plt.show()

# %% [markdown]
# ### Normalized 3D Vector Visualization (Subset Data)

# %%
# Extract the data for EI, TF, and JP from the df_ dataframe
data_3d_subset = df_[['EI', 'TF', 'JP']].to_numpy()
names_3d_subset = df_['Name'].tolist()

# Normalize the data to make all vectors have a length of 1
norms_3d_subset = np.linalg.norm(data_3d_subset, axis=1)
normalized_data_3d_subset = data_3d_subset / norms_3d_subset[:, np.newaxis]

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plotting vectors from origin (0,0,0)
origin_3d_subset = np.zeros(normalized_data_3d_subset.shape)

# Create a list of colors, one for each data point
colors_3d_subset = plt.cm.viridis(np.linspace(0, 1, len(normalized_data_3d_subset)))

ax.quiver(origin_3d_subset[:, 0], origin_3d_subset[:, 1], origin_3d_subset[:, 2], normalized_data_3d_subset[:, 0], normalized_data_3d_subset[:, 1], normalized_data_3d_subset[:, 2], color=colors_3d_subset, length=1, normalize=False)

# Set labels
ax.set_xlabel('EI')
ax.set_ylabel('TF')
ax.set_zlabel('JP')

ax.set_title('3D Vector Representation of EI, TF, and JP (Subset Data, Normalized)')

# Setting limits to see the vectors clearly
# Since vectors are normalized to length 1, the limits can be set to be slightly larger than 1
ax.set_xlim([-1.1, 1.1])
ax.set_ylim([-1.1, 1.1])
ax.set_zlim([-1.1, 1.1])

# Add text labels at the end of each arrow
for i in range(len(normalized_data_3d_subset)):
    ax.text(normalized_data_3d_subset[i, 0], normalized_data_3d_subset[i, 1], normalized_data_3d_subset[i, 2], names_3d_subset[i])

plt.show()

# %% [markdown]
# ### Display Subset 3D Data

# %%
print(data_3d_subset)
# Out:
# [[ 0.64 -0.4   0.14]
#  [ 0.4  -0.2   0.6 ]
#  [ 0.4   0.1   0.7 ]
#  [ 0.22  0.5   0.78]
#  [ 0.52 -0.08 -0.12]
#  [-0.84 -0.78 -0.96]
#  [-0.5  -0.12  0.02]
#  [ 0.56 -0.6   0.8 ]
#  [-0.44  0.04 -0.12]
#  [ 0.02 -0.04 -0.12]]

# %% [markdown]
# ### Display Normalized Subset 3D Data

# %%
print(normalized_data_3d_subset)
# Out:
# [[ 0.83377449 -0.52110906  0.18238817]
#  [ 0.53452248 -0.26726124  0.80178373]
#  [ 0.49236596  0.12309149  0.86164044]
#  [ 0.23102923  0.52506643  0.81910362]
#  [ 0.96362411 -0.14824986 -0.22237479]
#  [-0.56180065 -0.52167203 -0.64205788]
#  [-0.97165259 -0.23319662  0.0388661 ]
#  [ 0.48860337 -0.52350361  0.69800481]
#  [-0.96107446  0.08737041 -0.26211122]
#  [ 0.15617376 -0.31234752 -0.93704257]]

# %% [markdown]
# ### Display Subset Names

# %%
print(names_3d_subset)
# Out:
# ['검은고양이', '김주호', '미뇽', '박선주', '수달', '최민지', 'Marcus rashford', 'O', '김아연', 'joy']

# %% [markdown]
# ### Calculate Dot Products (3D Subset Data)

# %%
ref = 1
for i in range(len(data_3d_subset)):
    dp_val = np.dot(data_3d_subset[ref], data_3d_subset[i])
    print(f'dot product of {names_3d_subset[ref]} and {names_3d_subset[i]} = {round(dp_val, 2)}')
# Out:
# dot product of 김주호 and 검은고양이 = 0.42
# dot product of 김주호 and 김주호 = 0.56
# dot product of 김주호 and 미뇽 = 0.56
# dot product of 김주호 and 박선주 = 0.46
# dot product of 김주호 and 수달 = 0.15
# dot product of 김주호 and 최민지 = -0.76
# dot product of 김주호 and Marcus rashford = -0.16
# dot product of 김주호 and O = 0.82
# dot product of 김주호 and 김아연 = -0.26
# dot product of 김주호 and joy = -0.06

# %% [markdown]
# ### Calculate Dot Products (Normalized 3D Subset Data)

# %%
ref = 1
for i in range(len(normalized_data_3d_subset)):
    dp_val = np.dot(normalized_data_3d_subset[ref], normalized_data_3d_subset[i])
    print(f'dot product of {names_3d_subset[ref]} and {names_3d_subset[i]} = {round(dp_val, 2)}')
# Out:
# dot product of 김주호 and 검은고양이 = 0.73
# dot product of 김주호 and 김주호 = 1.0
# dot product of 김주호 and 미뇽 = 0.92
# dot product of 김주호 and 박선주 = 0.64
# dot product of 김주호 and 수달 = 0.38
# dot product of 김주호 and 최민지 = -0.68
# dot product of 김주호 and Marcus rashford = -0.43
# dot product of 김주호 and O = 0.96
# dot product of 김주호 and 김아연 = -0.75
# dot product of 김주호 and joy = -0.58

# %% [markdown]
# ### Extract Full 4D Data and Normalize

# %%
# Extract the data for EI, NS, TF, and JP from the df_ dataframe
data_4d_subset = df_[['EI', 'NS','TF', 'JP']].to_numpy()
names_4d_subset = df_['Name'].tolist()

# Normalize the data to make all vectors have a length of 1
norms_4d_subset = np.linalg.norm(data_4d_subset, axis=1)
normalized_data_4d_subset = data_4d_subset / norms_4d_subset[:, np.newaxis]

# %% [markdown]
# ### Calculate Dot Products (Full 4D Subset Data)

# %%
ref = 1
for i in range(len(data_4d_subset)):
    dp_val = np.dot(data_4d_subset[ref], data_4d_subset[i])
    print(f'dot product of {names_4d_subset[ref]} and {names_4d_subset[i]} = {round(dp_val, 2)}')
# Out:
# dot product of 김주호 and 검은고양이 = 0.49
# dot product of 김주호 and 김주호 = 0.6
# dot product of 김주호 and 미뇽 = 0.72
# dot product of 김주호 and 박선주 = 0.32
# dot product of 김주호 and 수달 = 0.2
# dot product of 김주호 and 최민지 = -0.73
# dot product of 김주호 and Marcus rashford = -0.16
# dot product of 김주호 and O = 0.8
# dot product of 김주호 and 김아연 = -0.19
# dot product of 김주호 and joy = 0.06

# %% [markdown]
# ### Calculate Dot Products (Normalized 4D Subset Data)

# %%
ref = 1
for i in range(len(normalized_data_4d_subset)):
    dp_val = np.dot(normalized_data_4d_subset[ref], normalized_data_4d_subset[i])
    print(f'dot product of {names_4d_subset[ref]} and {names_4d_subset[i]} = {round(dp_val, 2)}')
# Out:
# dot product of 김주호 and 검은고양이 = 0.75
# dot product of 김주호 and 김주호 = 1.0
# dot product of 김주호 and 미뇽 = 0.82
# dot product of 김주호 and 박선주 = 0.36
# dot product of 김주호 and 수달 = 0.43
# dot product of 김주호 and 최민지 = -0.63
# dot product of 김주호 and Marcus rashford = -0.4
# dot product of 김주호 and O = 0.9
# dot product of 김주호 and 김아연 = -0.44
# dot product of 김주호 and joy = 0.13

# %% [markdown]
# ### Visualize AAT Matrix

# %%
AAT = np.matmul(normalized_data_4d_subset,normalized_data_4d_subset.transpose())
print(np.round(AAT,2))
# Out:
# [[ 1.    0.75  0.61 -0.18  0.86 -0.25 -0.61  0.69 -0.44  0.42]
#  [ 0.75  1.    0.82  0.36  0.43 -0.63 -0.4   0.9  -0.44  0.13]
#  [ 0.61  0.82  1.    0.12  0.44 -0.58 -0.31  0.48 -0.    0.56]
#  [-0.18  0.36  0.12  1.   -0.24 -0.81 -0.28  0.39 -0.59 -0.72]
#  [ 0.86  0.43  0.44 -0.24  1.   -0.27 -0.83  0.32 -0.45  0.45]
#  [-0.25 -0.63 -0.58 -0.81 -0.27  1.    0.64 -0.45  0.59  0.23]
#  [-0.61 -0.4  -0.31 -0.28 -0.83  0.64  1.   -0.33  0.76  0.01]
#  [ 0.69  0.9   0.48  0.39  0.32 -0.45 -0.33  1.   -0.63 -0.19]
#  [-0.44 -0.44 -0.   -0.59 -0.45  0.59  0.76 -0.63  1.    0.57]
#  [ 0.42  0.13  0.56 -0.72  0.45  0.23  0.01 -0.19  0.57  1.  ]]

# %%
import seaborn as sns
plt.figure(figsize=(16, 12))
sns.heatmap(AAT, annot=True, cmap='RdBu', fmt=".2f", xticklabels=names_4d_subset, yticklabels=names_4d_subset)
plt.title('Similarity Matrix')
#plt.xlabel('Names')
#plt.ylabel('Names')
plt.show()
